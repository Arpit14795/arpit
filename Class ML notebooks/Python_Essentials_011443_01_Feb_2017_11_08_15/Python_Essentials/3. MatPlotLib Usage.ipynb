# %% [markdown]
# # Matplotlib
# ## Lets learn basic plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# # Plotting

# %%
x = [0,1,2]
y = [0,1,4]

# %%
fig = plt.figure()
axes = fig.add_subplot(111)
axes.plot(x, y)
plt.show()

# %% [markdown]
# ## Using NumPy to increase the the number of data points

# %%
x_highres = np.linspace(0, 2, 20)
y_highres = x_highres ** 2

# %%
fig = plt.figure()
axes = fig.add_subplot(111)

axes.plot(x, y)
axes.plot(x_highres, y_highres)

plt.show()

# %% [markdown]
# ## Controlling Line Style

# %%
fig = plt.figure()
axes = fig.add_subplot(111)

#axes.plot(x_highres, y_highres, "r--")
axes.plot(x_highres, y_highres, color="red")

plt.show()

# %%
fig = plt.figure()
axes = fig.add_subplot(111)

axes.plot(x_highres, y_highres, color="red", linestyle='dashed',  linewidth=5)

plt.show()

# %%
fig = plt.figure()
axes = fig.add_subplot(111)

axes.plot(x_highres, y_highres,color="red", linestyle='dashed',  linewidth=3, marker='o',
         markerfacecolor='blue', markersize=5)

plt.show()

# %% [markdown]
# ## Line Styles & Markers

# %% [markdown]
# ```
# ================    ===============================
# character           description
# ================    ===============================
# ``'-'``             solid line style
# ``'--'``            dashed line style
# ``'-.'``            dash-dot line style
# ``':'``             dotted line style
# ``'.'``             point marker
# ``','``             pixel marker
# ``'o'``             circle marker
# ``'v'``             triangle_down marker
# ``'^'``             triangle_up marker
# ``'<'``             triangle_left marker
# ``'>'``             triangle_right marker
# ``'1'``             tri_down marker
# ``'2'``             tri_up marker
# ``'3'``             tri_left marker
# ``'4'``             tri_right marker
# ``'s'``             square marker
# ``'p'``             pentagon marker
# ``'*'``             star marker
# ``'h'``             hexagon1 marker
# ``'H'``             hexagon2 marker
# ``'+'``             plus marker
# ``'x'``             x marker
# ``'D'``             diamond marker
# ``'d'``             thin_diamond marker
# ``'|'``             vline marker
# ``'_'``             hline marker
# ================    ===============================
# ```

# %% [markdown]
# ## Colors

# %% [markdown]
# ```
# ==========  ========
# character   color
# ==========  ========
# 'b'         blue
# 'g'         green
# 'r'         red
# 'c'         cyan
# 'm'         magenta
# 'y'         yellow
# 'k'         black
# 'w'         white
# ==========  ========
#
# In addition, you can specify colors in many weird and
# wonderful ways, including full names (``'green'``), hex
# strings (``'#008000'``), RGB or RGBA tuples (``(0,1,0,1)``) or
# grayscale intensities as a string (``'0.8'``).  Of these, the
# string specifications can be used in place of a ``fmt`` group,
# but the tuple forms can be used only as ``kwargs``.
# ```

# %% [markdown]
# # Title and Grid

# %%
fig = plt.figure()
axes = fig.add_subplot(111)

axes.plot(x_highres, y_highres,color="red", linestyle='dashed',  linewidth=3, marker='o',
         markerfacecolor='blue', markersize=5)

axes.set_title('bebfjrebfg') ## Notice you can you LaTeX Code
                          
axes.grid()

plt.show()

# %% [markdown]
# # Axis Labels

# %%
fig = plt.figure()
axes = fig.add_subplot(111)

axes.plot(x_highres, y_highres,color="red", linestyle='dashed',  linewidth=3, marker='o',
         markerfacecolor='blue', markersize=5)

axes.set_title('$y=x^2$')
axes.grid()
axes.set_xlabel('x')
axes.set_ylabel('y')

plt.show()

# %% [markdown]
# # Controlling the Figure Size

# %%
fig = plt.figure(figsize=(5,6))
axes = fig.add_subplot(111)

axes.plot(x_highres, y_highres,color="red", linestyle='dashed',  linewidth=3, marker='o',
         markerfacecolor='blue', markersize=5)

axes.set_title('$y=x^2$')
axes.grid()
axes.set_xlabel('x')
axes.set_ylabel('y')

plt.show()

# %% [markdown]
# # Visualizing Numbers as images

# %%
noise = np.random.random((128,128))
noise
# Out:
# array([[ 0.64823713,  0.68173014,  0.64640691, ...,  0.80650921,
#          0.91471992,  0.0069721 ],
#        [ 0.94201985,  0.15172863,  0.26046217, ...,  0.10140072,
#          0.03242253,  0.11080421],
#        [ 0.47215486,  0.32894886,  0.27890423, ...,  0.94919042,
#          0.64689593,  0.23277554],
#        ...,
#        [ 0.36588252,  0.15969425,  0.00395866, ...,  0.38448597,
#          0.83144098,  0.39003417],
#        [ 0.13885042,  0.66968564,  0.97258737, ...,  0.41591496,
#          0.88300811,  0.95437044],
#        [ 0.44542023,  0.73774067,  0.34585198, ...,  0.17096208,
#          0.73783937,  0.81434344]])

# %%
plt.imshow(noise)
plt.show()

# %% [markdown]
# ## Color Bar

# %%
plt.imshow(noise)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Color Maps

# %%
plt.imshow(noise, cmap=plt.cm.gray)
plt.colorbar()
plt.show()

# %%
plt.imshow(noise, cmap=plt.cm.Paired)
plt.colorbar()
plt.show()
